# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import os
import re
import datetime
import time
from scipy.stats import gaussian_kde
import pysal as ps

basepath = '/home/akagi/Documents/wecc_form_714'

path_d = {
1993: '93WSCC1/WSCC',
1994: '94WSCC1/WSCC1994',
1995: '95WSCC1',
1996: '96WSCC1/WSCC1996',
1997: '97wscc1',
1998: '98WSCC1/WSCC1',
1999: '99WSCC1/WSCC1',
2000: '00WSCC1/WSCC1',
2001: '01WECC/WECC01/wecc01',
2002: 'WECCONE3/WECC One/WECC2002',
2003: 'WECC/WECC/WECC ONE/wecc03',
2004: 'WECC_2004/WECC/WECC One/ferc',
2006: 'form714-database_2006_2013/form714-database/Part 3 Schedule 2 - Planning Area Hourly Demand.csv'
}

util = {
'aps' : 803,
'srp' : 16572,
'ldwp' : 11208
        }
util_2006 = {
'aps' : 116,
'srp' : 244,
'ldwp' : 194

}

df_path_d = {}

def build_paths():
    for y in path_d.keys():
        if y < 2006:
            pathstr = basepath + '/' + path_d[y]
            dirstr = ' '.join(os.listdir(pathstr))
#            print dirstr
            for u in util.keys():
                if not u in df_path_d:
                    df_path_d.update({u : {}})
                srcstr = '%s\d\d.dat' % (u)
 #               print srcstr
                match = re.search(srcstr, dirstr, re.I)
#                print type(match.group())
                rpath = pathstr + '/' + match.group()
                df_path_d[u].update({y : rpath})
        elif y == 2006:
            pathstr = basepath + '/' + path_d[y]
            for u in util.keys():
                if not u in df_path_d:
                    df_path_d.update({u : {}})
                df_path_d[u].update({y : pathstr})

df_d = {}

def build_df():
    for u in df_path_d.keys():
        df = pd.DataFrame()
        for y in df_path_d[u].keys():
            if y < 2006:
#                print df_path_d[u][y]
                f = open(df_path_d[u][y])
                r = f.readlines()
                r = [g.replace('\t', '      ') for g in r if len(g) > 70]
                for i in range(0, len(r)-1, 2):
                    entry = [r[i], r[i+1]]
                    mo = int(r[i][:2])
                    day = int(r[i][2:4])
                    yr = r[i][4:6]
                    if yr[0] == '0':
                        yr = int('20' + yr)
                    else:
                        yr = int('19' + yr)

                    am = [int(j) for j in entry[0][20:].split()]
                    pm = [int(j) for j in entry[1][20:].split()]
                    ampm = am + pm
                    entry_df = pd.DataFrame()
                    dt_ix = pd.date_range(start=datetime.datetime(yr, mo, day, 0), end=datetime.datetime(yr, mo, day, 23), freq='H')
                    entry_df['load'] = ampm
#                    print entry_df
                    entry_df.index = dt_ix
                    df = df.append(entry_df)
#                    print entry_df
            elif y == 2006:
                f = pd.read_csv('%s/%s' % (basepath, path_d[y]))
                f = f.loc[f['respondent_id'] == util_2006[u], [u'plan_date', u'hour01', u'hour02', u'hour03', u'hour04', u'hour05', u'hour06', u'hour07', u'hour08', u'hour09', u'hour10', u'hour11', u'hour12', u'hour13', u'hour14', u'hour15', u'hour16', u'hour17', u'hour18', u'hour19', u'hour20', u'hour21', u'hour22', u'hour23', u'hour24']]
                f['plan_date'] = f['plan_date'].str.split().apply(lambda x: x[0]).apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y'))
                f = f.set_index('plan_date').stack().reset_index().rename(columns={'level_1':'hour', 0:'load'})
                f['hour'] = f['hour'].str.replace('hour','').astype(int)-1
                f['date'] = f.apply(lambda x: datetime.datetime(x['plan_date'].year, x['plan_date'].month, x['plan_date'].day, x['hour']), axis=1)
                f = pd.DataFrame(f.set_index('date')['load'])
                df = pd.concat([df, f], axis=0)
        
	df['year'] = [i.year for i in df.index]
        df_d.update({u : df})

# %%
def plot_curvefit(xdata, ydata):
    xy = np.vstack([xdata,ydata])
    z = gaussian_kde(xy)(xy)
    scatter(xdata, ydata, c=z, s=100, edgecolor='')

# %%
build_paths()
build_df()

# %%
#### Import census data

az_census = pd.read_csv('/home/akagi/Dropbox/NSF WSC AZ WEN Team Share/trans_and_dist/az_census.csv', index_col=0).T
az_census.index = az_census.index.astype(int)

ca_census = pd.read_csv('/home/akagi/Dropbox/NSF WSC AZ WEN Team Share/trans_and_dist/ca_census.csv', index_col=0).T
ca_census.index = ca_census.index.astype(int)

# %%
#### Regress by year for each utility

#### SRP

srp_regress = pd.concat([az_census['Maricopa'], df_d['srp'].groupby('year').mean()], axis=1, join='inner')

a, b = np.polyfit(srp_regress['Maricopa'], srp_regress['load'], 1)
y, p = np.polyfit(range(len(srp_regress)), srp_regress['Maricopa'], 1)
df_d['srp']['pop_est'] = [((y/(365*24))*x + p) for x in range(len(df_d['srp']))]
df_d['srp']['load_trend'] = df_d['srp']['pop_est'].apply(lambda x: a*x + b)
df_d['srp']['load_detrend'] = df_d['srp']['load'] - df_d['srp']['load_trend']

#### APS

aps_regress = pd.concat([az_census.sum(axis=1), df_d['aps'].groupby('year').mean()], axis=1, join='inner')

a2, b2 = np.polyfit(aps_regress[0], aps_regress['load'], 1)
y2, p2 = np.polyfit(range(len(aps_regress)), aps_regress[0], 1)
df_d['aps']['pop_est'] = [((y2/(365*24))*x + p2) for x in range(len(df_d['aps']))]
df_d['aps']['load_trend'] = df_d['aps']['pop_est'].apply(lambda x: a2*x + b2)
df_d['aps']['load_detrend'] = df_d['aps']['load'] - df_d['aps']['load_trend']

#### LDWP

ldwp_regress = pd.concat([ca_census['LosAngeles'], df_d['ldwp'].groupby('year').mean()], axis=1, join='inner')

a3, b3 = np.polyfit(ldwp_regress['LosAngeles'], ldwp_regress['load'], 1)
y3, p3 = np.polyfit(range(len(ldwp_regress)), ldwp_regress['LosAngeles'], 1)
df_d['ldwp']['pop_est'] = [((y3/(365*24))*x + p3) for x in range(len(df_d['ldwp']))]
df_d['ldwp']['load_trend'] = df_d['ldwp']['pop_est'].apply(lambda x: a3*x + b3)
df_d['ldwp']['load_detrend'] = df_d['ldwp']['load'] - df_d['ldwp']['load_trend']

# %% [markdown]
# ## First, the effect of population growth is removed from total load

# %% [markdown]
# A regression between population and average annual load is constructed. The linear regression ("long memory component") is subtracted from the measured hourly load to isolate the "short memory component"--i.e. the change in load that is attributable to changes in temperature.

# %%
scatter(srp_regress['Maricopa']/1000, srp_regress['load'])
xlabel('Population, Maricopa County (thousands)')
ylabel('Average Yearly Load (MW)')
title('Average Annual Load vs. Population, SRP')

# %% [markdown]
# ## The load anomaly represents the portion of the load that can be attributed to temperature changes

# %% [markdown]
# Note that the load's intra-annual range increases over time.

# %%
plot(df_d['srp'].index, df_d['srp']['load'], label='Total Load')
plot(df_d['srp'].index, df_d['srp']['load_detrend'], label='Load Anomaly')
legend(loc=2)
xlabel('Time')
ylabel('Load (MW)')
title('Load and Detrended Load, SRP')

# %% [markdown]
# ## Example analysis for SRP

# %%
phxsh = pd.read_csv('/home/akagi/Desktop/sha_hist.csv')

phxsh['date'] = phxsh['DATE'].apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))

phxsh = phxsh.set_index('date')

phxsh['tmax'] = phxsh['TMAX'].apply(lambda x: float(str(x)[:-1] + '.' + str(x)[-1]))

phxsh['tmin'] = phxsh['TMIN'].apply(lambda x: float(str(x)[:-1] + '.' + str(x)[-1]))

df = pd.DataFrame(index=pd.date_range(start=datetime.date(1961,1,1), end=datetime.date(2014,2,25), freq='H'))

tmax = pd.DataFrame(phxsh['tmax']).set_index(pd.Series([datetime.datetime(i.year, i.month, i.day, 12) for i in phxsh['tmax'].index])).rename(columns={'tmax':'temp'})

tmin = pd.DataFrame(phxsh['tmin']).set_index(pd.Series([datetime.datetime(i.year, i.month, i.day, 0) for i in phxsh['tmin'].index])).rename(columns={'tmin':'temp'})
 
tmaxmin = pd.concat([tmax, tmin])
trange = pd.concat([df, tmaxmin], axis=1)
trange['temp'] = trange['temp'].interpolate('time')
trange['temp'].loc[trange['temp'] < -100] = np.nan

normtemp = (trange['temp'] - trange['temp'].mean()) / (trange['temp'].max() - trange['temp'].min())
cat = pd.concat([df_d['srp'], normtemp], axis=1, join='inner')
cat['date'] = cat.index

cat['year'] = [i.year for i in cat['date']]
cat['month'] = [i.month for i in cat['date']]
cat['day'] = [i.day for i in cat['date']]

summercat = cat.loc[cat['date'].apply(lambda x: x.month).isin([6,7,8])]

# %% [markdown]
# ## Temperature-load relationship exhibits hysteresis

# %%
plot_curvefit(summercat['temp'], summercat['load_detrend'])
xlabel('Temperature Anomaly')
ylabel('Load Anomaly')
title('Temperature-load relationship, SRP\nSummer Months')
colorbar(label='Kernel Density')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f6409a78680>

# %% [markdown]
# The lower curve of the hysteresis loop represents morning hours, while the upper curve represents afternoon hours.

# %% [markdown]
# ## Temperature-load response has become steeper over the years, but has decreased since the 2008 recession

# %%
g = summercat.groupby(['year', 'month', 'day']).max().reset_index()
scatter(g['temp'], g['load_detrend'], c=g['year'], linewidth=0, alpha=0.7)
colorbar(label='Year', ticks=[1993,1995,1997,1999,2001,2003,2005,2007,2009,2011,2013])
ylabel('Load Anomaly')
xlabel('Temperature Anomaly')
title('Temperature-load response, SRP, 1993-2013\nSummer Months, Peak Loads')

# %%
kwargs={}
kwargs['smoothing'] = 14

h = cat.groupby(['year', 'month', 'day']).max().reset_index()
for i in [1993, 1999, 2006, 2012]:
    t = h.loc[h['year'] == i, 'load_detrend']
    plot(pd.rolling_mean(t, kwargs['smoothing']).fillna(pd.rolling_mean(t.iloc[-(kwargs['smoothing']+1):].append(t.iloc[:kwargs['smoothing']]), kwargs['smoothing'])), label=i)
    
legend()
xlim(0,366)
xlabel('Day of year')
ylabel('Load Anomaly')
title('Peak Load Anomaly, SRP, 1993-2004')

# %%
#hmin = cat.groupby(['year', 'month', 'day']).min().reset_index()
#for i in [1993, 1998, 2004]:
#    plot(hmin.loc[h['year'] == i, 'load_detrend'], label=i)
    
#legend()
#xlim(0,366)
#xlabel('Day of year')
#ylabel('Load Anomaly')
#title('Min. Load Anomaly, SRP, 1993-2004')

# %% [markdown]
# ## Check assessor database for clues

# %%
mc = pd.read_csv('/home/akagi/Desktop/assessor/mc_2014.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (10,25,26,28,29,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %% [markdown]
# ## Rise in temperature-load response can at least partly be explained by greater average housing square footage

# %%
ann_load_anom = g.groupby('year').mean()['load_detrend']
bar(ann_load_anom.index, ann_load_anom)
ylabel('Average annual summertime peak load anomaly')
xlabel('Year')
title('Average summertime peak load anomaly vs. year')

# %%
avg_livingsqft = mc.groupby('CNSTN_YR').sum()['LIV_AREA'].cumsum() / mc.groupby('CNSTN_YR').size().cumsum()
mod_livingsqft = avg_livingsqft.loc[1993:2013]
plot(mod_livingsqft.index, mod_livingsqft.values)
ylabel('Average Living Square Footage')
xlabel('Year')
title('Average building square footage vs. time')
xlim(1993,2013)
# Out:
# (1993, 2013)

# %% [markdown]
# ## Some correlation between building square footage and temperature-load response

# %%
#fig, ax = subplots()

scatter(mod_livingsqft.drop(2005), ann_load_anom, c=ann_load_anom.index)
xlabel('Average Living Square Footage')
ylabel('Average Summertime Peak Load Anomaly')
suptitle('Effect of building square footage on temperature-load response')
colorbar(label='Year', ticks=[1993,1995,1997,1999,2001,2003,2005,2007,2009,2011,2013])
print '\n', 'r = %s' % (mod_livingsqft.drop(2005).corr(ann_load_anom.interpolate())), '\n\n'
# Out:
# r = 0.775217317128

# %% [markdown]
# ## Economic activity also seems to have an impact on the temperature-load response; let's compare labor force size to load anomaly

# %%
labor = pd.read_excel('/home/akagi/Dropbox/NSF WSC AZ WEN Team Share/trans_and_dist/az_labor_stats.xlsx', skiprows=10).iloc[:, :-1]

# %%
labor = labor.set_index('Year').stack().reset_index().rename(columns={'level_1':'month', 0:'laborforce'})

# %%
labor['date'] = labor['Year'].astype(str) + labor['month']
labor['date'] = labor['date'].apply(lambda x: datetime.datetime.strptime(x, '%Y%b'))
labor = labor[['date', 'laborforce']]
labor['year'] = [i.year for i in labor['date']]
labor['month'] = [i.month for i in labor['date']]

# %%
mon_labor = labor.groupby(['year', 'month']).mean()
mon_load_anom = g.groupby(['year', 'month']).mean()['load_detrend']

# %%
laborcat = pd.concat([mon_labor, mon_load_anom], axis=1).dropna(subset=['load_detrend']).reset_index()

# %%
print '\n', 'r = %s' % (laborcat['load_detrend'].corr(laborcat['laborforce'])), '\n\n'
scatter(laborcat['laborforce']/1000, laborcat['load_detrend'], c=laborcat['month'])
xlabel('Labor Force (thousands)')
ylabel('Monthly Load Anomaly (MW)')
title('Labor force size vs. load anomaly')
colorbar(label='Month', ticks=[6,7,8])
# Out:
# r = 0.837100984927
# <matplotlib.colorbar.Colorbar instance at 0x7f63f8e41320>

# %% [markdown]
# ## On the other hand, load anomaly exhibits a very poor correlation with labor force ratio (labor force divided by total population), meaning that the initial detrending process could be flawed.

# %%
azpop = pd.DataFrame(az_census.sum(axis=1)).reset_index()
azpop = azpop.rename(columns={'index':'year', 0:'pop'})
azpop['month'] = 6

pop_ts = pd.DataFrame(index=pd.date_range(datetime.date(1993,1,1), datetime.date(2013, 1, 1), freq='M'))
pop_ts['year'] = [i.year for i in pop_ts.index]
pop_ts['month'] = [i.month for i in pop_ts.index]
pop_ts[0] = 0

popcat = pd.concat([azpop.groupby(['year', 'month']).mean(), mon_labor], axis=1).dropna(subset=['laborforce'])
popcat['pop'] = popcat['pop'].interpolate()
popcat['lf_ratio'] = popcat['laborforce']/popcat['pop']

#plot(popcat['lf_ratio'])

lfrcat = pd.concat([popcat['lf_ratio'], mon_load_anom], axis=1).dropna(subset=['load_detrend']).reset_index()
print '\n', 'r = %s' % (lfrcat['load_detrend'].corr(lfrcat['lf_ratio'])), '\n\n'
scatter(lfrcat['lf_ratio'], lfrcat['load_detrend'], c=laborcat['month'])
xlabel('Labor Force Ratio')
ylabel('Monthly Load Anomaly (MW)')
title('Labor force ratio vs. load anomaly')
colorbar(label='Month', ticks=[6,7,8])
# Out:
# r = -0.177574853703
# <matplotlib.colorbar.Colorbar instance at 0x7f63f8c81cb0>

# %% [markdown]
# ## Others factors affecting temperature-load reponse could include:

# %% [markdown]
# - A/C penetration rate
# - Utility-based load management plans
# - Increased building energy efficiency
# - Increased utilization of non-utility distributed generation
# - Electricity prices
# - Disparity between population change in county and population change in utility service area could introduce error in the initial 'detrending'.

# %% [markdown]
# ### Census analysis

# %%
df = pd.read_excel('/home/akagi/Downloads/h08.xls', skiprows=59, skipfooter=1)
df = df.set_index('State').drop(np.nan)
df = df = df.stack().reset_index()
df['level_1'] = df['level_1'].astype(str)
df = df.drop(df.loc[df['level_1'].astype(str).str.contains('Unnamed')].index)
df['level_1'] = df['level_1'].str.replace('\(.*\)', '').str.strip().astype(int)
df[0] = df[0].astype(int)
df = df.rename(columns={0: 'hh_income', 'level_1': 'year'})
hhi = df.groupby(['State', 'year']).mean()

# %% [markdown]
# ### Look at effect of household income

# %%
plot(hhi.loc['Arizona'].index, hhi.loc['Arizona'])
xlabel('Year')
ylabel('Median household income')
title('Median household income')
xlim(1987,2013)
# Out:
# (1987, 2013)

# %%
hhi_anom = pd.concat([ann_load_anom, hhi.loc['Arizona']], axis=1)

print 'r =', hhi_anom['hh_income'].corr(hhi_anom['load_detrend'])
print '\n'
scatter(hhi_anom['hh_income'], hhi_anom['load_detrend'])
xlabel('Median household income')
ylabel('Average Load Anomaly')
title('Median household income vs. load anomaly')
# Out:
# r = 0.422134159988

# %%
price = pd.read_excel('/home/akagi/Downloads/sept08az.xls', skiprows=2, skipfooter=1).iloc[15:, :-3].set_index('Sector').T.reset_index()
price['index'] = price['index'].str.replace('\n', '').astype(int)
price = price.rename(columns={'index':'year'}).sort('year').set_index('year')
price
# Out:
# Sector  Residential  Commercial  Industrial  Other  Transportation  Total
# year
# 1990           9.04        8.29        5.58   5.41             NaN   7.75
# 1991           9.14        8.30        5.58   6.14             NaN   7.85
# 1992           9.58        8.64        5.76   5.74             NaN   8.13
# 1993           9.65        8.70        5.80   5.64             NaN   8.21
# 1994           9.30        8.32        5.63   5.47             NaN   7.93
# 1995           9.09        8.06        5.26   5.15             NaN   7.62
# 1996           8.95        7.97        5.19   5.39             NaN   7.54
# 1997           8.82        7.83        5.05   4.84             NaN   7.38
# 1998           8.68        7.76        5.12   4.43             NaN   7.33
# 1999           8.53        7.51        5.04   4.66             NaN   7.23
# 2000           8.44        7.34        5.27   4.53             NaN   7.25
# 2001           8.30        7.37        5.24   4.93             NaN   7.27
# 2002           8.27        7.28        5.20   4.56             NaN   7.21
# 2003           8.35        7.09        5.37    NaN             NaN   7.34
# 2004           8.46        7.28        5.35    NaN             NaN   7.45
# 2005           8.86        7.40        5.85    NaN             NaN   7.79
# 2006           9.40        8.02        5.69    NaN             NaN   8.24
# 2007           9.66        8.27        6.05    NaN             NaN   8.54
# 2008          10.27        8.93        6.57    NaN             NaN   9.11
# 2009          10.73        9.35        6.65    NaN             NaN   9.56
# 2010          10.97        9.47        6.63    NaN             NaN   9.69
# 2011          11.08        9.50        6.55    NaN               0   9.71
# 2012          11.29        9.53        6.53    NaN               0   9.81

# %%
price_hhi = pd.concat([price, hhi_anom], axis=1)[['Total', 'load_detrend', 'hh_income']].dropna()
price_hhi['ratio'] = 100*price_hhi['Total']/price_hhi['hh_income']

# %%
scatter(price_hhi['ratio'], price_hhi['load_detrend'])
xlabel('Ratio of electricity price to household income')
ylabel('Load Anomaly')
title('Affordability of electricity vs. Load Anomaly')

# %%
scatter(price_hhi['Total'], price_hhi['load_detrend'])
xlabel('Electricity Price')
ylabel('Load Anomaly')
title('Electricity price vs. Load Anomaly')

# %% [markdown]
# ## Parse EIA-861 data

# %%
import string

basepath_861 = '/home/akagi/Documents/eia_form_861'

path_d = {
1990: 'f86190',
1991: 'f86191',
1992: 'f86192',
1993: 'f86193',
1994: 'f86194',
1995: 'f86195',
1996: 'f86196',
1997: 'f86197',
1998: 'f86198',
1999: 'f86199',
2000: 'f86100',
2001: '2001',
2002: '2002',
2003: '2003',
2004: '2004',
2005: '2005',
2006: 'f86106',
2007: '2007',
2008: '2008',
2009: '2009',
2010: 'f86110',
2011: 'f86111',
2012: 'f8612012',
}

#util = {
#'aps' : 803,
#'srp' : 16572,
#'ldwp' : 11208
#        }
#util_2006 = {
#'aps' : 116,
#'srp' : 244,
#'ldwp' : 194

#}

sales = pd.DataFrame()

#pre_1999 = pd.DataFrame()

def make_sales():
    
    pre_1999 = pd.DataFrame()
    post_1999 = pd.DataFrame()
    post_2001 = pd.DataFrame()
    post_2007 = pd.DataFrame()
    post_2008 = pd.DataFrame()
    
    for y in path_d.keys():
        if 1990 <= y <= 1991:
            df = pd.read_excel('%s/%s/F861TYP1.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            pre_1999 = pre_1999.append(df)
        if 1992 <= y <= 1998:
            df = pd.read_excel('%s/%s/F861TYP1.xls'  % (basepath_861, path_d[y]))
            df['YEAR'] = y
            pre_1999 = pre_1999.append(df)

    #### File_ format starts here
    
        if y == 1999:
            df = pd.read_excel('%s/%s/FILE2.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_1999 = post_1999.append(df)
        if y == 2000:
            df = pd.read_excel('%s/%s/FILE2.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_1999 = post_1999.append(df)

        if 2001 <= y <= 2006:
            df = pd.read_excel('%s/%s/file2.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_2001 = post_2001.append(df)

        if y == 2007:
            df = pd.read_excel('%s/%s/file2_%s.xls' % (basepath_861, path_d[y], y))
#            df['YEAR'] = y
            post_2007 = post_2007.append(df)            
        if 2008 <= y <= 2011:
            df = pd.read_excel('%s/%s/file2_%s.xls' % (basepath_861, path_d[y], y), skiprows=2)
            df['YEAR'] = y
            post_2008 = post_2008.append(df)
            
#### REFORMAT PRE-1999

    c_ser = pd.Series(pre_1999.columns)
    test = pre_1999.loc[:, c_ser[c_ser.str.contains('[A-Z]\d_|UTILCODE|YEAR')]]
    t1 = test.loc[:, pd.Series(test.columns)[pd.Series(test.columns).str.contains('1_|UTILCODE|YEAR')]]
    t2 = test.loc[:, pd.Series(test.columns)[pd.Series(test.columns).str.contains('2_|UTILCODE|YEAR')]]
    t1.columns = pd.Series(t1.columns).str.replace('1_', '_')
    t2.columns = pd.Series(t2.columns).str.replace('2_', '_')
    pre_1999_r = pd.concat([t1,t2]).rename(columns={'STCODE_1':'STATE'})#.groupby(['UTILCODE', 'STCODE_1']).mean()
    pre_1999_r.columns = pd.Series(pre_1999_r.columns).str.replace('_1', '_RES').str.replace('_2', '_COM').str.replace('_3', '_IND').str.replace('_4', '_HWY').str.replace('_5', '_OTH').str.replace('_6', '_TOT')

#### REFORMAT POST-1999

    post_1999.columns = pd.Series(post_1999.columns).str.replace('([A-Z]+)(SALES).*', '\\2_\\1').str.replace('([A-Z]+)(CONS).*', '\\2_\\1').str.replace('([A-Z]+)(REV).*', '\\2_\\1').str.replace('CONS_', 'CONSUM_').str.replace('SALES', 'MWH')

#### REFORMAT POST-2001   

    post_2001.columns = pd.Series(post_2001.columns).str.upper().str.replace('([A-Z]+) (REV).*', '\\2_\\1').str.replace('([A-Z]+) (SALES).*', '\\2_\\1').str.replace('([A-Z]+) (CONSUM).*', '\\2_\\1').str.replace('TRANS', 'HWY').str.replace('SALES', 'MWH').str.replace('UTILITY_ID', 'UTILCODE').str.replace('TOTAL', 'TOT')

#### REFORMAT POST-2007

    post_2007.columns = pd.Series(post_2007.columns).str.upper().str.replace('([A-Z]+)_(REV).*', '\\2_\\1').str.replace('([A-Z]+)_(SALES).*', '\\2_\\1').str.replace('([A-Z]+)_(CONSUM).*', '\\2_\\1').str.replace('RESIDENTIAL', 'RES').str.replace('COMMERCIAL', 'COM').str.replace('INDUSTRIAL', 'IND').str.replace('TRANSPORTATION', 'HWY').str.replace('UTILITY_ID', 'UTILCODE').str.replace('STATE_CODE', 'STATE').str.replace('SALES', 'MWH').str.replace('TOTAL', 'TOT')

#### REFORMAT POST-2008

    post_2008.columns = pd.Series(post_2008.columns).str.upper().str.replace('THOUSANDS DOLLARS', 'REV_').str.replace('MEGAWATTHOURS', 'MWH_').str.replace('COUNT', 'CONSUM_').str.replace('_$', '_RES').str.replace('\.1', 'COM').str.replace('\.2', 'IND').str.replace('\.3', 'HWY').str.replace('\.4', 'TOT').replace('UTILITY NUMBER', 'UTILCODE')
    
    df_return = pd.concat([pre_1999_r, post_1999, post_2001, post_2007, post_2008], join='inner')
    
    for i in df_return.iloc[:, 3:]:
        df_return[i] = df_return[i].astype(str).str.replace('\.\d*', '').str.replace('[^0-9]', '').replace('', np.nan).astype(float)
        
    return df_return

# %%
sales = make_sales()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
srp = sales.groupby(['UTILCODE', 'STATE', 'YEAR']).mean().loc[803].reset_index()

# %%
srp
# Out:
#    STATE  YEAR   MWH_RES  CONSUM_RES  REV_COM   MWH_COM  CONSUM_COM  REV_IND  \
# 0     AZ  1990   5777871      523705   571806   6567728       66558   174048
# 1     AZ  1991   5856791      535319   585951   6726350       67416   178220
# 2     AZ  1992   6066830      549778   631797   6904072       68650   188879
# 3     AZ  1993   6247002      565791   646022   7040026       69885   188441
# 4     AZ  1994   6873300      586866   632454   7456049       71620   177154
# 5     AZ  1995   6848905      610505   653425   7768289       74020   166097
# 6     AZ  1996   7541440      636239   678130   8233762       76708   171771
# 7     AZ  1997   7970309      663493   687988   8524882       79754   173402
# 8     AZ  1998   8310689      689610   699220   8697397       83221   178900
# 9     AZ  1999   8774822      716638   733038   9431119       85071   166703
# 10    AZ  2000   9768654      744124   771256  10044996       88391   151992
# 11    AZ  2001  10334860      776339   805326  10504044       93499   135638
# 12    AZ  2002  10443820      801801   795998  10589065       95575   125759
# 13    AZ  2003  11147195      828366   823463  11066410       99415   134044
# 14    AZ  2004  11527402      859069   842856  11402140      103386   137872
# 15    AZ  2005  12223613     1007718   894633  11842700      107374   147228
# 16    AZ  2006  12901612      936464  1067405  12251092      111560   172193
# 17    AZ  2007  13771481      979138  1177356  12977708      118361   177286
# 18    AZ  2008  13368015      986363  1252774  13003518      121218   192127
# 19    AZ  2009  13214097      992077  1286772  12745766      121316   179858
# 20    AZ  2010  13035500      996422  1270274  12503880      121740   170264
# 21    AZ  2011  13290230      994244  1286842  12731496      122248   171428
#
#     MWH_IND  CONSUM_IND  REV_HWY  MWH_HWY  CONSUM_HWY  REV_TOT   MWH_TOT  \
# 0   2858232        4362    12830    65157         475  1338425  15273760
# 1   2956667        4163    12770    66856         479  1367472  15611458
# 2   2989976        3922    12601    68984         483  1482053  16034731
# 3   3002761        3888    12229    70548         495  1512151  16364964
# 4   3058658        3918    12537    71880         506  1497756  17464834
# 5   3053039        3831    12447    73653         522  1501916  17748711
# 6   3161132        3833    12864    79098         574  1584856  19020696
# 7   3235646        3965    11757    80870         612  1620168  19816927
# 8   3364070        3893    10476    85794         638  1655452  20463083
# 9   2661018        3943    11120    89532         679  1716236  20961836
# 10  2597836        3614    10540    92915         717  1814035  22509131
# 11  2460297        3686    11663    99810        1013  1867338  23399011
# 12  2224922        3671    11553   103948         982  1845556  23361755
# 13  2348700        3681      NaN      NaN         NaN  1917812  24562305
# 14  2578341        3730        0        0           0  1964254  25507883
# 15  2411273        3793        0        0           0  2121083  26477586
# 16  2817693        3871        0        0           0  2510010  27970397
# 17  2422132        3938        0        0           0  2772957  29171321
# 18  2422055        3913        0        0           0  2899977  28793588
# 19  2213433        3806      NaN      NaN         NaN  2961907  28173296
# 20  2170083        3777      NaN      NaN         NaN  2944575  27709463
# 21  2188600        3744      NaN      NaN         NaN  3001406  28210326
#
#     CONSUM_TOT
# 0       595379
# 1       607647
# 2       623100
# 3       640322
# 4       663169
# 5       689131
# 6       717610
# 7       748069
# 8       777614
# 9       806569
# 10      837063
# 11      874537
# 12      902029
# 13      931462
# 14      966185
# 15     1118885
# 16     1051895
# 17     1101437
# 18     1111494
# 19     1117199
# 20     1121939
# 21     1120236

# %%
plot(srp['YEAR'], srp['MWH_TOT'])
plot(srp['YEAR'], srp['MWH_RES'])
plot(srp['YEAR'], srp['MWH_COM'])
plot(srp['YEAR'], srp['MWH_IND'])

xlim(1990, 2011)
# Out:
# (1990, 2011)

# %%
plot(srp['YEAR'], srp['CONSUM_TOT'])
plot(srp['YEAR'], srp['CONSUM_RES'])
plot(srp['YEAR'], srp['CONSUM_COM'])
plot(srp['YEAR'], srp['CONSUM_IND'])
xlim(1990, 2011)
# Out:
# (1990, 2011)

# %%
plot(srp['YEAR'], srp['MWH_TOT']/srp['CONSUM_TOT'])

# %%
def make_dsm():
    
    pre_1992 = pd.DataFrame()
    post_1992 = pd.DataFrame()
    post_1999 = pd.DataFrame()
    post_2001 = pd.DataFrame()
    post_2007 = pd.DataFrame()
    post_2008 = pd.DataFrame()
    
    for y in path_d.keys():
        if 1990 <= y <= 1991:
            df = pd.read_excel('%s/%s/F861TYP2.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            pre_1992 = pre_1992.append(df)
        if 1992 <= y <= 1998:
            df = pd.read_excel('%s/%s/F861TY2A.xls'  % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_1992 = post_1992.append(df)

    #### File_ format starts here
    
        if y == 1999:
            df = pd.read_excel('%s/%s/FILE4.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_1999 = post_1999.append(df)
        if y == 2000:
            df = pd.read_excel('%s/%s/FILE4.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_1999 = post_1999.append(df)

        if 2001 <= y <= 2006:
            df = pd.read_excel('%s/%s/file3.xls' % (basepath_861, path_d[y]))
            df['YEAR'] = y
            post_2001 = post_2001.append(df)

        if y == 2007:
            df = pd.read_excel('%s/%s/file3_%s.xls' % (basepath_861, path_d[y], y))
#            df['YEAR'] = y
            post_2007 = post_2007.append(df)            
        if 2008 <= y <= 2011:
            df = pd.read_excel('%s/%s/file3_%s.xls' % (basepath_861, path_d[y], y))
            df['YEAR'] = y
            post_2008 = post_2008.append(df)
            
    return [pre_1992, post_1992, post_1999, post_2001, post_2007, post_2008]
            
#### REFORMAT PRE-1999

#    c_ser = pd.Series(pre_1999.columns)
#    test = pre_1999.loc[:, c_ser[c_ser.str.contains('[A-Z]\d_|UTILCODE|YEAR')]]
#    t1 = test.loc[:, pd.Series(test.columns)[pd.Series(test.columns).str.contains('1_|UTILCODE|YEAR')]]
#    t2 = test.loc[:, pd.Series(test.columns)[pd.Series(test.columns).str.contains('2_|UTILCODE|YEAR')]]
#    t1.columns = pd.Series(t1.columns).str.replace('1_', '_')
#    t2.columns = pd.Series(t2.columns).str.replace('2_', '_')
#    pre_1999_r = pd.concat([t1,t2]).rename(columns={'STCODE_1':'STATE'})#.groupby(['UTILCODE', 'STCODE_1']).mean()
#    pre_1999_r.columns = pd.Series(pre_1999_r.columns).str.replace('_1', '_RES').str.replace('_2', '_COM').str.replace('_3', '_IND').str.replace('_4', '_HWY').str.replace('_5', '_OTH').str.replace('_6', '_TOT')

#### REFORMAT POST-1999

#    post_1999.columns = pd.Series(post_1999.columns).str.replace('([A-Z]+)(SALES).*', '\\2_\\1').str.replace('([A-Z]+)(CONS).*', '\\2_\\1').str.replace('([A-Z]+)(REV).*', '\\2_\\1').str.replace('CONS_', 'CONSUM_').str.replace('SALES', 'MWH')

#### REFORMAT POST-2001   

#    post_2001.columns = pd.Series(post_2001.columns).str.upper().str.replace('([A-Z]+) (REV).*', '\\2_\\1').str.replace('([A-Z]+) (SALES).*', '\\2_\\1').str.replace('([A-Z]+) (CONSUM).*', '\\2_\\1').str.replace('TRANS', 'HWY').str.replace('SALES', 'MWH').str.replace('UTILITY_ID', 'UTILCODE').str.replace('TOTAL', 'TOT')

#### REFORMAT POST-2007

#    post_2007.columns = pd.Series(post_2007.columns).str.upper().str.replace('([A-Z]+)_(REV).*', '\\2_\\1').str.replace('([A-Z]+)_(SALES).*', '\\2_\\1').str.replace('([A-Z]+)_(CONSUM).*', '\\2_\\1').str.replace('RESIDENTIAL', 'RES').str.replace('COMMERCIAL', 'COM').str.replace('INDUSTRIAL', 'IND').str.replace('TRANSPORTATION', 'HWY').str.replace('UTILITY_ID', 'UTILCODE').str.replace('STATE_CODE', 'STATE').str.replace('SALES', 'MWH').str.replace('TOTAL', 'TOT')

#### REFORMAT POST-2008

#    post_2008.columns = pd.Series(post_2008.columns).str.upper().str.replace('THOUSANDS DOLLARS', 'REV_').str.replace('MEGAWATTHOURS', 'MWH_').str.replace('COUNT', 'CONSUM_').str.replace('_$', '_RES').str.replace('\.1', 'COM').str.replace('\.2', 'IND').str.replace('\.3', 'HWY').str.replace('\.4', 'TOT').replace('UTILITY NUMBER', 'UTILCODE')
    
#    df_return = pd.concat([pre_1999_r, post_1999, post_2001, post_2007, post_2008], join='inner')
    
#    for i in df_return.iloc[:, 3:]:
#        df_return[i] = df_return[i].astype(str).str.replace('\.\d*', '').str.replace('[^0-9]', '').replace('', np.nan).astype(float)
        
#    return df_return

# %%
dsm = make_dsm()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
dsm[0].columns
# Out:
# Index([u'UTILRECTYP', u'UTILCODE', u'PEAKLOADRE', u'PEAKLOADCO', u'PEAKLOADIN', u'PEAKLOADOT', u'REDUCTDSM', u'REDUCTDLC', u'REDUCTINTE', u'REDUCTCONS', u'DIRLCONT1', u'DIRLCONT2', u'DIRLCONT3', u'DIRLCONT4', u'DIRLCONT5', u'DIRLCONT6', u'DIRLCONT7', u'DIRLCONT8', u'DIRLCONT9', u'DIRLCONT10', u'DIRLCONT11', u'INTLOAD1', u'INTLOAD2', u'INTLOAD3', u'INTLOAD4', u'INTLOAD5', u'INTLOAD6', u'INTLOAD7', u'INTLOAD8', u'INTLOAD9', u'INTLOAD10', u'INTLOAD11', u'CONSOTH1', u'CONSOTH2', u'CONSOTH3', u'CONSOTH4', u'CONSOTH5', u'CONSOTH6', u'CONSOTH7', u'CONSOTH8', u'CONSOTH9', u'CONSOTH10', u'CONSOTH11', u'ENERSAV1', u'ENERSAV2', u'ENERSAV3', u'ENERSAV4', u'ENERSAV5', u'ENERSAV6', u'ENERSAV7', u'ENERSAV8', u'ENERSAV9', u'ENERSAV10', u'ENERSAV11', u'DSMEXPEN1', u'DSMEXPEN2', u'DSMEXPEN3', u'DSMEXPEN4', u'DSMEXPEN5', u'DSMEXPEN6', u'DSMEXPEN7', u'DSMEXPEN8', u'DSMEXPEN9', u'DSMEXPEN10', u'DSMEXPEN11', u'YEAR'], dtype='object')

# %%
dsm[1].columns
# Out:
# Index([u'ADMIN1', u'ADMIN2', u'ADMIN3', u'DIRUTLCST1', u'DIRUTLCST2', u'DIRUTLCST3', u'DLC1', u'DLC2', u'DLC3', u'DLC_APR1', u'DLC_APR2', u'DLC_APR3', u'DLC_APR4', u'DLC_APR5', u'DLC_APR6', u'DLC_APR7', u'DLC_APR8', u'DLC_APRA1', u'DLC_APRB1', u'DLC_EE1', u'DLC_EE2', u'DLC_EE3', u'DLC_EE4', u'DLC_EE5', u'DLC_EE6', u'DLC_EE7', u'DLC_EE8', u'DLC_EEA1', u'DLC_EEB1', u'DLC_PPR1', u'DLC_PPR2', u'DLC_PPR3', u'DLC_PPR4', u'DLC_PPR5', u'DLC_PPR6', u'DLC_PPR7', u'DLC_PPR8', u'DLC_PPRA1', u'DLC_PPRB1', u'EE1', u'EE2', u'EE3', u'EE_APR1', u'EE_APR2', u'EE_APR3', u'EE_APR4', u'EE_APR5', u'EE_APR6', u'EE_APR7', u'EE_APR8', u'EE_APRA1', u'EE_APRB1', u'EE_EE1', u'EE_EE2', u'EE_EE3', u'EE_EE4', u'EE_EE5', u'EE_EE6', u'EE_EE7', u'EE_EE8', u'EE_EEA1', u'EE_EEB1', u'IB_APGB1', u'IB_EEB1', u'IL1', u'IL2', u'IL3', u'IL_APR1', u'IL_APR2', u'IL_APR3', u'IL_APR4', u'IL_APR5', u'IL_APR6', u'IL_APR7', u'IL_APR8', u'IL_APRA1', u'IL_APRB1', u'IL_EE1', u'IL_EE2', u'IL_EE3', u'IL_EE4', u'IL_EE5', u'IL_EE6', u'IL_EE7', u'IL_EE8', u'IL_EEA1', u'IL_EEB1', u'IL_PPR1', u'IL_PPR2', u'IL_PPR3', u'IL_PPR4', u'IL_PPR5', u'IL_PPR6', u'IL_PPR7', u'IL_PPR8', u'IL_PPRA1', u'IL_PPRB1', u'INDRTCST1', u'INDRTCST2', u'INDRTCST3', ...], dtype='object')

# %%
dsm[2].columns
# Out:
# Index([u'AK', u'ECAR', u'EE_A', u'EE_APC_A', u'EE_APC_I', u'EE_API_A', u'EE_API_I', u'EE_APO_A', u'EE_APO_I', u'EE_APR_A', u'EE_APR_I', u'EE_EEC_A', u'EE_EEC_I', u'EE_EEIO_A', u'EE_EEI_A', u'EE_EEI_I', u'EE_EEO_I', u'EE_EER_A', u'EE_EER_I', u'ERCOT', u'FRCC', u'HI', u'INDRTCST_A', u'LM_A', u'LM_APC_A', u'LM_APC_I', u'LM_API_A', u'LM_API_I', u'LM_APO_A', u'LM_APO_I', u'LM_APR_A', u'LM_APR_I', u'LM_EEC_A', u'LM_EEC_I', u'LM_EEI_A', u'LM_EEI_I', u'LM_EEO_A', u'LM_EEO_I', u'LM_EER_A', u'LM_EER_I', u'LM_PPC_A', u'LM_PPC_I', u'LM_PPI_A', u'LM_PPI_I', u'LM_PPO_A', u'LM_PPO_I', u'LM_PPR_A', u'LM_PPR_I', u'MAAC', u'MAIN', u'MAPP', u'NERCLOC', u'NPCC', u'OWNERSHIP', u'PR', u'SALECONS', u'SALERESALE', u'SERC', u'SPP', u'TOTUTCOST_', u'UTILCODE', u'UTILNAME', u'WSCC', u'YEAR'], dtype='object')

# %%
dsm[3].columns
# Out:
# Index([u'DIRECTCOSTEEF', u'DIRECTCOSTLM', u'EEAPCA', u'EEAPCI', u'EEAPIA', u'EEAPII', u'EEAPOA', u'EEAPOI', u'EEAPRA', u'EEAPRI', u'EEEECA', u'EEEECI', u'EEEEIA', u'EEEEII', u'EEEEOA', u'EEEEOI', u'EEEERA', u'EEEERI', u'EEFACTUALPEAKANNCOM', u'EEFACTUALPEAKANNIND', u'EEFACTUALPEAKANNOTH', u'EEFACTUALPEAKANNRES', u'EEFACTUALPEAKINCCOM', u'EEFACTUALPEAKINCIND', u'EEFACTUALPEAKINCOTH', u'EEFACTUALPEAKINCRES', u'EE_C', u'EE_INCENT', u'ENERGYEFFANNCOM', u'ENERGYEFFANNIND', u'ENERGYEFFANNOTH', u'ENERGYEFFANNRES', u'ENERGYEFFINCCOMM', u'ENERGYEFFINCIND', u'ENERGYEFFINCOTH', u'ENERGYEFFINCRES', u'INCENTIVEEEF', u'INCENTIVELM', u'INDIRECTCOST', u'LMACTUALPEAKREDANNCOM', u'LMACTUALPEAKREDANNIND', u'LMACTUALPEAKREDANNOTH', u'LMACTUALPEAKREDANNRES', u'LMACTUALPEAKREDINCCOM', u'LMACTUALPEAKREDINCIND', u'LMACTUALPEAKREDINCOTH', u'LMACTUALPEAKREDINCRES', u'LMAPCA', u'LMAPCI', u'LMAPIA', u'LMAPII', u'LMAPOA', u'LMAPOI', u'LMAPRA', u'LMAPRI', u'LMEECA', u'LMEECI', u'LMEEIA', u'LMEEII', u'LMEEOA', u'LMEEOI', u'LMEERA', u'LMEERI', u'LMPOTENTPEAKREDANNCOM', u'LMPOTENTPEAKREDANNIND', u'LMPOTENTPEAKREDANNOTH', u'LMPOTENTPEAKREDANNRES', u'LMPOTENTPEAKREDINCCOM', u'LMPOTENTPEAKREDINCIND', u'LMPOTENTPEAKREDINCOTH', u'LMPOTENTPEAKREDINCRES', u'LMPPCA', u'LMPPCI', u'LMPPIA', u'LMPPII', u'LMPPOA', u'LMPPOI', u'LMPPRA', u'LMPPRI', u'LM_C', u'LM_INCENT', u'LOADMNGEFFANNCOM', u'LOADMNGEFFANNIND', u'LOADMNGEFFANNOTH', u'LOADMNGEFFANNRES', u'LOADMNGEFFINCCOM', u'LOADMNGEFFINCIND', u'LOADMNGEFFINCOTH', u'LOADMNGEFFINCRES', u'NERC LOC', u'NERC_LOCATION', u'OWNERSHIP', u'Owner Code', u'Owner Type', u'RETAIL_SALES', u'SALESCONS', u'SALESRESAL', u'SALES_FOR_RESALE', u'TOTALCOST', u'UTILITY CODE', ...], dtype='object')

# %%
dsm[4].columns
# Out:
# Index([u'year', u'utility_id', u'UTILITY_NAME', u'OWNERSHIP', u'NERC_LOCATION', u'RETAIL_SALES', u'SALES_FOR_RESALE', u'ENERGYEFFINCRES', u'ENERGYEFFINCCOMM', u'ENERGYEFFINCIND', u'ENERGYEFFINCOTH', u'ENERGYEFFANNRES', u'ENERGYEFFANNCOM', u'ENERGYEFFANNIND', u'ENERGYEFFANNOTH', u'EEFACTUALPEAKINCRES', u'EEFACTUALPEAKINCCOM', u'EEFACTUALPEAKINCIND', u'EEFACTUALPEAKINCOTH', u'EEFACTUALPEAKANNRES', u'EEFACTUALPEAKANNCOM', u'EEFACTUALPEAKANNIND', u'EEFACTUALPEAKANNOTH', u'LOADMNGEFFINCRES', u'LOADMNGEFFINCCOM', u'LOADMNGEFFINCIND', u'LOADMNGEFFINCOTH', u'LOADMNGEFFANNRES', u'LOADMNGEFFANNCOM', u'LOADMNGEFFANNIND', u'LOADMNGEFFANNOTH', u'LMPOTENTPEAKREDINCRES', u'LMPOTENTPEAKREDINCCOM', u'LMPOTENTPEAKREDINCIND', u'LMPOTENTPEAKREDINCOTH', u'LMPOTENTPEAKREDANNRES', u'LMPOTENTPEAKREDANNCOM', u'LMPOTENTPEAKREDANNIND', u'LMPOTENTPEAKREDANNOTH', u'LMACTUALPEAKREDINCRES', u'LMACTUALPEAKREDINCCOM', u'LMACTUALPEAKREDINCIND', u'LMACTUALPEAKREDINCOTH', u'LMACTUALPEAKREDANNRES', u'LMACTUALPEAKREDANNCOM', u'LMACTUALPEAKREDANNIND', u'LMACTUALPEAKREDANNOTH', u'DIRECTCOSTEEF', u'INCENTIVEEEF', u'DIRECTCOSTLM', u'INCENTIVELM', u'INDIRECTCOST', u'TOTALCOST', u'DEMAND_SIDE_MANAGEMENT', u'REPORTED_AS_OTHER_COMP', u'INDEPENDENT_VERIFIY', u'MAJORCHANGES', u'PRICERESPONSIVE', u'PRICERESPRES', u'PRICERESPCOM', u'PRICERESPIND', u'PRICERESPOTH', u'TIMERESPONSIVE', u'TIMERESPRES', u'TIMERESPCOM', u'TIMERESPIND', u'TIMERESPTRANS'], dtype='object')

# %%
dsm[5].columns
# Out:
# Index([u'DATA_STATUS', u'DEMAND_SIDE_MANAGEMENT', u'DIRECTCOSTEEF', u'DIRECTCOSTLM', u'EEFACTUALPEAKANNCOM', u'EEFACTUALPEAKANNIND', u'EEFACTUALPEAKANNOTH', u'EEFACTUALPEAKANNRES', u'EEFACTUALPEAKINCCOM', u'EEFACTUALPEAKINCIND', u'EEFACTUALPEAKINCOTH', u'EEFACTUALPEAKINCRES', u'ENERGYEFFANNCOM', u'ENERGYEFFANNIND', u'ENERGYEFFANNOTH', u'ENERGYEFFANNRES', u'ENERGYEFFINCCOMM', u'ENERGYEFFINCIND', u'ENERGYEFFINCOTH', u'ENERGYEFFINCRES', u'INCENTIVEEEF', u'INCENTIVELM', u'INDEPENDENT_VERIFIY', u'INDIRECTCOST', u'LMACTUALPEAKREDANNCOM', u'LMACTUALPEAKREDANNIND', u'LMACTUALPEAKREDANNOTH', u'LMACTUALPEAKREDANNRES', u'LMACTUALPEAKREDINCCOM', u'LMACTUALPEAKREDINCIND', u'LMACTUALPEAKREDINCOTH', u'LMACTUALPEAKREDINCRES', u'LMPOTENTPEAKREDANNCOM', u'LMPOTENTPEAKREDANNIND', u'LMPOTENTPEAKREDANNOTH', u'LMPOTENTPEAKREDANNRES', u'LMPOTENTPEAKREDINCCOM', u'LMPOTENTPEAKREDINCIND', u'LMPOTENTPEAKREDINCOTH', u'LMPOTENTPEAKREDINCRES', u'LOADMNGEFFANNCOM', u'LOADMNGEFFANNIND', u'LOADMNGEFFANNOTH', u'LOADMNGEFFANNRES', u'LOADMNGEFFINCCOM', u'LOADMNGEFFINCIND', u'LOADMNGEFFINCOTH', u'LOADMNGEFFINCRES', u'MAJORCHANGES', u'NERC_LOCATION', u'OWNERSHIP', u'PRICERESPCOM', u'PRICERESPIND', u'PRICERESPONSIVE', u'PRICERESPOTH', u'PRICERESPRES', u'REPORTED_AS_OTHER_COMP', u'RETAIL_SALES', u'SALES_FOR_RESALE', u'TIMERESPCOM', u'TIMERESPIND', u'TIMERESPONSIVE', u'TIMERESPRES', u'TIMERESPTRANS', u'TOTALCOST', u'UTILITY_ID', u'UTILITY_NAME', u'Unnamed: 0', u'Unnamed: 1', u'Unnamed: 10', u'Unnamed: 100', u'Unnamed: 101', u'Unnamed: 11', u'Unnamed: 12', u'Unnamed: 13', u'Unnamed: 14', u'Unnamed: 15', u'Unnamed: 16', u'Unnamed: 17', u'Unnamed: 18', u'Unnamed: 19', u'Unnamed: 2', u'Unnamed: 20', u'Unnamed: 21', u'Unnamed: 22', u'Unnamed: 23', u'Unnamed: 24', u'Unnamed: 25', u'Unnamed: 26', u'Unnamed: 27', u'Unnamed: 28', u'Unnamed: 29', u'Unnamed: 3', u'Unnamed: 30', u'Unnamed: 31', u'Unnamed: 32', u'Unnamed: 33', u'Unnamed: 34', u'Unnamed: 35', u'Unnamed: 36', ...], dtype='object')

# %%
from StringIO import StringIO

# %%
fields_1990 = pd.read_excel('/home/akagi/Documents/eia_form_861/f86190/DataElementsDef90-00.xls', header=1)

fields_1990['Field Name'] = fields_1990['Field Name'].str.strip()
fields_1990['Definition'] = fields_1990['Definition'].str.replace('(^.*Part [A-Z]) +([A-Z].*$)', '\\2').str.replace('(^.*edule) +([A-Z].*$)', '\\2').str.replace(',', '').str.replace('-', ' ').str.replace(' +', ' ')

eff_1990 = fields_1990[fields_1990['Definition'].str.lower().str.contains('efficiency')]

dsm_1990 = fields_1990[fields_1990['Definition'].str.lower().str.contains('total dsm')]

# %%
eff_1990_2 = eff_1990[~eff_1990['Definition'].str.contains('Projected')]['Definition'].str.replace('(.*)(Residential).*', '\\2 \\1')\
.str.replace('(.*)(Commercial).*', '\\2 \\1').str.replace('(.*)(Industrial).*', '\\2 \\1').str.replace('(.*)(Other).*', '\\2 \\1')\
.str.replace('(Energy Efficiency) (Incremental) Effects (Actual)', '\\2 \\1 \\3').str.replace('(Energy Efficiency) (Annual) Effects (Actual)', '\\2 \\1 \\3')\
.str.strip()

# %%
dsm_1990_2 = dsm_1990['Definition'].str.replace('(.*)(Residential).*', '\\2 \\1').str.replace('(.*)(Commercial).*', '\\2 \\1')\
.str.replace('(.*)(Industrial).*', '\\2 \\1').str.replace('(.*)(Other).*', '\\2 \\1').str.replace('Total DSM Programs', 'Load Management')\
.str.replace('(Load Management) (Incremental) Effects (Actual|Energy|Potential)', '\\2 \\1 \\3')\
.str.replace('(Load Management) (Annual) Effects (Actual|Energy|Potential)', '\\2 \\1 \\3')\
.str.strip()

dsm_1990_2 = dsm_1990_2[~dsm_1990_2.str.contains('Projected')].str.strip()

# %%
#fields_1990[fields_1990['Definition'].str.contains('Cost')]

# %%
print len(eff_1990_2)
print len(dsm_1990_2)
# Out:
# 9
# 25

# %%
for i in eff_1990_2:
    print i
# Out:
# Direct Utility Cost Energy Efficiency Current Year
# Residential Incremental Energy Efficiency Actual Peak Reduction
# Commercial Incremental Energy Efficiency Actual Peak Reduction
# Industrial Incremental Energy Efficiency Actual Peak Reduction
# Other Incremental Energy Efficiency Actual Peak Reduction
# Residential Annual Energy Efficiency Actual Peak Reduction
# Commercial Annual Energy Efficiency Actual Peak Reduction
# Industrial Annual Energy Efficiency Actual Peak Reduction
# Other Annual Energy Efficiency Actual Peak Reduction

# %%
for i in dsm_1990_2:
    print i
# Out:
# Residential Incremental Load Management Actual Peak Reduction
# Commercial Incremental Load Management Actual Peak Reduction
# Industrial Incremental Load Management Actual Peak Reduction
# Other Incremental Load Management Actual Peak Reduction
# Residential Annual Load Management Actual Peak Reduction
# Commercial Annual Load Management Actual Peak Reduction
# Industrial Annual Load Management Actual Peak Reduction
# Other Annual Load Management Actual Peak Reduction
# Residential Incremental Load Management Energy Effects
# Commercial Incremental Load Management Energy Effects
# Industrial Incremental Load Management Energy Effects
# Other Incremental Load Management Energy Effects
# Residential Annual Load Management Energy Effects
# Commercial Annual Load Management Energy Effects
# Industrial Annual Load Management Energy Effects
# Other Annual Load Management Energy Effects
# Residential Incremental Load Management Potential Peak Reduction
# Commercial Incremental Load Management Potential Peak Reduction
# Industrial Incremental Load Management Potential Peak Reduction
# Other Incremental Load Management Potential Peak Reduction
# Residential Annual Load Management Potential Peak Reduction
# Commercial Annual Load Management Potential Peak Reduction
# Industrial Annual Load Management Potential Peak Reduction
# Other Annual Load Management Potential Peak Reduction
# Total DSM Cost Current Year

# %%
strfields_2001 = '''UTIL_CODE	Utility Code
UTIL_NAME	Utility Name
OWNERSHIP	Type of Ownership
NERC_LOC	NERC Location
SALESCONS	Sales to Ultimate Consumers
SALESRESAL	Sales for Resale
EEEERI	Residential Incremental Energy Efficiency Energy Effects 
EEEECI	Commercial Incremental Energy Efficiency Energy Effects
EEEEII	Industrial Incremental Energy Efficiency Energy Effects
EEEEOI	Other Incremental Energy Efficiency Energy Effects
EEEERA	Residential Annual Energy Efficiency Energy Effects 
EEEECA	Commercial Annual Energy Efficiency Energy Effects
EEEEIA	Industrial Annual Energy Efficiency Energy Effects
EEEEOA	Other Annual Energy Efficiency Energy Effects
EEAPRRI	Residential Incremental Energy Efficiency Actual Peak Reduction
EEAPRCI	Commercial Incremental Energy Efficiency Actual Peak Reduction
EEAPRII	Industrial Incremental Energy Efficiency Actual Peak Reduction
EEAPROI	Other Incremental Energy Efficiency Actual Peak Reduction
EEAPRRA	Residential Annual Energy Efficiency Actual Peak Reduction
EEAPRCA	Commercial Annual Energy Efficiency Actual Peak Reduction
EEAPRIA	Industrial Annual Energy Efficiency Actual Peak Reduction
EEAPROA	Other Annual Energy Efficiency Actual Peak Reduction
LMEERI	Residential Incremental Load Management Energy Effects 
LMEECI	Commercial Incremental Load Management Energy Effects
LMEEII	Industrial Incremental Load Management Energy Effects
LMEEOI	Other Incremental Load Management Energy Effects
LMEERA	Residential Annual Load Management Energy Effects 
LMEECA	Commercial Annual Load Management Energy Effects
LMEEIA	Industrial Annual Load Management Energy Effects
LMEEOA	Other Annual Load Management Energy Effects
LMPPRRI	Residential Incremental Load Management Potential Peak Reduction
LMPPRCI	Commercial Incremental Load Management Potential Peak Reduction
LMPPRII	Industrial Incremental Load Management Potential Peak Reduction
LMPPROI	Other Incremental Load Management Potential Peak Reduction
LMPPRRA	Residential Annual Load Management Potential Peak Reduction
LMPPRCA	Commercial Annual Load Management Potential Peak Reduction
LMPPRIA	Industrial Annual Load Management Potential Peak Reduction
LMPPROA	Other Annual Load Management Potential Peak Reduction
LMAPRRI	Residential Incremental Load Management Actual Peak Reduction
LMAPRCI	Commercial Incremental Load Management Actual Peak Reduction
LMAPRII	Industrial Incremental Load Management Actual Peak Reduction
LMAPROI	Other Incremental Load Management Actual Peak Reduction
LMAPRRA	Residential Annual Load Management Actual Peak Reduction
LMAPRCA	Commercial Annual Load Management Actual Peak Reduction
LMAPRIA	Industrial Annual Load Management Actual Peak Reduction
LMAPROA	Other Annual Load Management Actual Peak Reduction
EE_C	Annual Energy Efficiency Cost
EE_INCENT	Annual Incentive Payment Energy Efficiency
LM_C	Annual Load Management Cost
LM_INCENT	Annual Incentive Payment Load Management
INDRTCST_A	Annual Indirect Utility Cost
TOTUTCST_A	Annual Total Utility Cost'''

# %%
strfields_2007 = '''
UTIL_CODE	Utility Code
UTIL_NAME	Utility Name
OWNERSHIP	Type of Ownership
NERC_LOC	NERC Location
SALESCONS	Sales to Ultimate Consumers
SALESRESAL	Sales for Resale
ENERGYEFFINCRES	Residential Incremental Energy Efficiency Energy Effects 
ENERGYEFFINCCOMM	Commercial Incremental Energy Efficiency Energy Effects
ENERGYEFFINCIND	Industrial Incremental Energy Efficiency Energy Effects
ENERGYEFFINCOTH	Other Incremental Energy Efficiency Energy Effects
ENERGYEFFANNRES	Residential Annual Energy Efficiency Energy Effects 
ENERGYEFFANNCOM	Commercial Annual Energy Efficiency Energy Effects
ENERGYEFFANNIND	Industrial Annual Energy Efficiency Energy Effects
ENERGYEFFANNOTH	Other Annual Energy Efficiency Energy Effects
EEFACTUALPEAKINCRES	Residential Incremental Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKINCCOM	Commercial Incremental Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKINCIND	Industrial Incremental Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKINCOTH	Other Incremental Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKANNRES	Residential Annual Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKANNCOM	Commercial Annual Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKANNIND	Industrial Annual Energy Efficiency Actual Peak Reduction
EEFACTUALPEAKANNOTH	Other Annual Energy Efficiency Actual Peak Reduction
LOADMNGEFFINCRES	Residential Incremental Load Management Energy Effects 
LOADMNGEFFINCCOM	Commercial Incremental Load Management Energy Effects
LOADMNGEFFINCCIND	Industrial Incremental Load Management Energy Effects
LOADMNGEFFINCOTH	Other Incremental Load Management Energy Effects
LOADMNGEFFANNRES	Residential Annual Load Management Energy Effects 
LOADMNGEFFANNCOM	Commercial Annual Load Management Energy Effects
LOADMNGEFFANNIND	Industrial Annual Load Management Energy Effects
LOADMNGEFFANNOTH	Other Annual Load Management Energy Effects
LMPOTENTPEAKREDINCRES	Residential Incremental Load Management Potential Peak Reduction
LMPOTENTPEAKREDINCCOM	Commercial Incremental Load Management Potential Peak Reduction
LMPOTENTPEAKREDINCIND	Industrial Incremental Load Management Potential Peak Reduction
LMPOTENTPEAKREDINCOTH	Other Incremental Load Management Potential Peak Reduction
LMPOTENTPEAKREDANNRES	Residential Annual Load Management Potential Peak Reduction
LMPOTENTPEAKREDANNCOM	Commercial Annual Load Management Potential Peak Reduction
LMPOTENTPEAKREDANNIND	Industrial Annual Load Management Potential Peak Reduction
LMPOTENTPEAKREDANNOTH	Other Annual Load Management Potential Peak Reduction
LMACTUALPEAKREDINCRES	Residential Incremental Load Management Actual Peak Reduction
LMACTUALPEAKREDINCCOM	Commercial Incremental Load Management Actual Peak Reduction
LMACTUALPEAKREDINCIND	Industrial Incremental Load Management Actual Peak Reduction
LMACTUALPEAKREDINCOTH	Other Incremental Load Management Actual Peak Reduction
LMACTUALPEAKREDANNRES	Residential Annual Load Management Actual Peak Reduction
LMACTUALPEAKREDANNCOM	Commercial Annual Load Management Actual Peak Reduction
LMACTUALPEAKREDANNIND	Industrial Annual Load Management Actual Peak Reduction
LMACTUALPEAKREDANNOTH	Other Annual Load Management Actual Peak Reduction
DIRECTCOSTEEF	Annual Energy Efficiency Cost
INCENTIVEEEF	Annual Incentive Payment Energy Efficiency
DIRECTCOSTLM	Annual Load Management Cost
INCENTIVELM	Annual Incentive Payment Load Management
INDIRECTCOST	Annual Indirect Utility Cost
TOTALCOST	Annual Total Utility Cost'''

# %%
strfields_2008 = '''
YEAR	Year of Data
UTIL_ID	Utility Code
UTILITY_NAME	Utility Name
OWNERSHIP	Ownership Type
NERC_LOCATION	NERC Location
RETAIL_SALES	Sales to retail consumers
SALES_FOR_RESALE	Sales for Resale 
ENERGYEFFINCRES	Residential Incremental Energy Efficiency Energy Effects 
ENERGYEFFINCCOMM	Commercial Incremental Energy Efficiency Energy Effects 
ENERGYEFFINCIND	Industrial Incremental Energy Efficiency Energy Effects 
ENERGYEFFINCOTH	Other Incremental Energy Efficiency Energy Effects 
ENERGYEFFANNRES	Residential Annual Energy Efficiency Energy Effects 
ENERGYEFFANNCOM	Commercial Annual Energy Efficiency Energy Effects 
ENERGYEFFANNIND	  Industrial Annual Energy Efficiency Energy Effects 
ENERGYEFFANNOTH	Other Annual Energy Efficiency Energy Effects 
EEFACTUALPEAKINCRES	Residential Incremental Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKINCCOM	Commercial Incremental Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKINCIND	Industrial Incremental Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKINCOTH	Other Incremental Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKANNRES	Residential Annual Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKANNCOM 	Commercial Annual Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKANNIND	Industrial Annual Energy Efficiency Actual Peak Reduction 
EEFACTUALPEAKANNOTH	Other Annual Energy Efficiency Actual Peak Reduction 
LOADMNGEFFINCRES	Residential Incremental Load Management Energy Effects 
LOADMNGEFFINCCOM	Commercial Incremental Load Management Energy Effects 
LOADMNGEFFINCCIND	Industrial Incremental Load Management Energy Effects 
LOADMNGEFFINCOTH	Other Incremental Load Management Energy Effects 
LOADMNGEFFANNRES	Residential Annual Load Management Energy Effects 
LOADMNGEFFANNCOM	Commercial Annual Load Management Energy Effects 
LOADMNGEFFANNIND	Industrial Annual Load Management Energy Effects 
LOADMNGEFFANNOTH	Other Annual Load Management Energy Effects 
LMPOTENTPEAKREDINCRES	Residential Incremental Load Management Potential Peak Reduction 
LMPOTENTPEAKREDINCCOM	Commercial Incremental Load Management Potential Peak Reduction 
LMPOTENTPEAKREDINCIND	Industrial Incremental Load Management Potential Peak Reduction 
LMPOTENTPEAKREDINCOTH	Other Incremental Load Management Potential Peak Reduction 
LMPOTENTPEAKREDANNRES	Residential Annual Load Management Potential Peak Reduction 
LMPOTENTPEAKREDANNCOM	Commercial Annual Load Management Potential Peak Reduction 
LMPOTENTPEAKREDANNIND	Industrial Annual Load Management Potential Peak Reduction 
LMPOTENTPEAKREDINCOTH	Other Annual Load Management Potential Peak Reduction 
LMACTUALPEAKREDINCRES	Residential Incremental Load Management Actual Peak Reduction 
LMACTUALPEAKREDINCCOM	Commercial Incremental Load Management Actual Peak Reduction 
LMACTUALPEAKREDINCIND	Industrial Incremental Load Management Actual Peak Reduction 
LMACTUALPEAKREDINCOTH	Other Incremental Load Management Actual Peak Reduction 
LMACTUALPEAKREDANNRES	Residential Annual Load Management Actual Peak Reduction 
LMACTUALPEAKREDANNCOM	Commercial Annual Load Management Actual Peak Reduction 
LMACTUALPEAKREDANNIND	Industrial Annual Load Management Actual Peak Reduction 
LMACTUALPEAKREDANNOTH	Other Annual Load Management Actual Peak Reduction 
DIRECTCOSTEEF	Annual Energy Efficiency Cost 
INCENTIVEEEF	Annual Incentive Payment Energy Efficiency 
DIRECTCOSTLM	Annual Load Management Cost 
INCENTIVELM	Annual Incentive Payment Load Management 
INDIRECTCOST	Annual Indirect Utility Cost 
TOTALCOST	Annual Total Utility Cost 
DEMAND_SIDE_MANAGEMENT	Entity has a company-administered DSM program 
REPORTED_AS_OTHER_COMP	Entity’s DSM activities are reported on Schedule 6 of another entity’s form EIA-861 
INDEPENDENT_VERIFY	Entity’s energy savings are verified through an independent evaluation 
MAJOR_CHANGES	Entity’s DSM programs have undergone major changes 
PRICERESPONSIVE	Entity operates incentive-based DSM programs 
PRICERESPRES	Number of residential consumers 
PRICERESPCOM	Number of commercial consumers 
PRICERESPIND	Number of industrial consumers 
PRICERESPOTH	Number of transportation consumers in incentive-based DSM programs
TIMERESPONSIVE	Entity operates time-based DSM programs 
TIMERESPRES	Number of residential consumers 
TIMERESPCOM	Number of commercial consumers 
TIMERESPIND	Number of industrial consumers 
TIMERESPTRANS	Number of transportation consumers in time-based DSM programs'''

# %%
fields_2001 = pd.read_csv(StringIO(strfields_2001), sep='\t', names=['slug_2001', 'desc'])
fields_2007 = pd.read_csv(StringIO(strfields_2007), sep='\t', names=['slug_2007', 'desc'])
fields_2008 = pd.read_csv(StringIO(strfields_2008), sep='\t', names=['slug_2008', 'desc'])

fields_2001['desc'] = fields_2001['desc'].str.lower().str.strip()
fields_2007['desc'] = fields_2007['desc'].str.lower().str.strip()
fields_2008['desc'] = fields_2008['desc'].str.lower().str.strip()

fields_2001.set_index('desc', inplace=True)
fields_2007.set_index('desc', inplace=True)
fields_2008.set_index('desc', inplace=True)

# %%
field_comb = pd.concat([fields_2001, fields_2007, fields_2008], axis=1, join='inner')

field_comb
# Out:
#                                                                    slug_2001  \
# desc
# utility code                                                       UTIL_CODE
# utility name                                                       UTIL_NAME
# nerc location                                                       NERC_LOC
# sales for resale                                                  SALESRESAL
# residential incremental energy efficiency energy effects              EEEERI
# commercial incremental energy efficiency energy effects               EEEECI
# industrial incremental energy efficiency energy effects               EEEEII
# other incremental energy efficiency energy effects                    EEEEOI
# residential annual energy efficiency energy effects                   EEEERA
# commercial annual energy efficiency energy effects                    EEEECA
# industrial annual energy efficiency energy effects                    EEEEIA
# other annual energy efficiency energy effects                         EEEEOA
# residential incremental energy efficiency actual peak reduction      EEAPRRI
# commercial incremental energy efficiency actual peak reduction       EEAPRCI
# industrial incremental energy efficiency actual peak reduction       EEAPRII
# other incremental energy efficiency actual peak reduction            EEAPROI
# residential annual energy efficiency actual peak reduction           EEAPRRA
# commercial annual energy efficiency actual peak reduction            EEAPRCA
# industrial annual energy efficiency actual peak reduction            EEAPRIA
# other annual energy efficiency actual peak reduction                 EEAPROA
# residential incremental load management energy effects                LMEERI
# commercial incremental load management energy effects                 LMEECI
# industrial incremental load management energy effects                 LMEEII
# other incremental load management energy effects                      LMEEOI
# residential annual load management energy effects                     LMEERA
# commercial annual load management energy effects                      LMEECA
# industrial annual load management energy effects                      LMEEIA
# other annual load management energy effects                           LMEEOA
# residential incremental load management potential peak reduction     LMPPRRI
# commercial incremental load management potential peak reduction      LMPPRCI
# industrial incremental load management potential peak reduction      LMPPRII
# other incremental load management potential peak reduction           LMPPROI
# residential annual load management potential peak reduction          LMPPRRA
# commercial annual load management potential peak reduction           LMPPRCA
# industrial annual load management potential peak reduction           LMPPRIA
# other annual load management potential peak reduction                LMPPROA
# residential incremental load management actual peak reduction        LMAPRRI
# commercial incremental load management actual peak reduction         LMAPRCI
# industrial incremental load management actual peak reduction         LMAPRII
# other incremental load management actual peak reduction              LMAPROI
# residential annual load management actual peak reduction             LMAPRRA
# commercial annual load management actual peak reduction              LMAPRCA
# industrial annual load management actual peak reduction              LMAPRIA
# other annual load management actual peak reduction                   LMAPROA
# annual energy efficiency cost                                           EE_C
# annual incentive payment energy efficiency                         EE_INCENT
# annual load management cost                                             LM_C
# annual incentive payment load management                           LM_INCENT
# annual indirect utility cost                                      INDRTCST_A
# annual total utility cost                                         TOTUTCST_A
#
#                                                                               slug_2007  \
# desc
# utility code                                                                  UTIL_CODE
# utility name                                                                  UTIL_NAME
# nerc location                                                                  NERC_LOC
# sales for resale                                                             SALESRESAL
# residential incremental energy efficiency energy effects                ENERGYEFFINCRES
# commercial incremental energy efficiency energy effects                ENERGYEFFINCCOMM
# industrial incremental energy efficiency energy effects                 ENERGYEFFINCIND
# other incremental energy efficiency energy effects                      ENERGYEFFINCOTH
# residential annual energy efficiency energy effects                     ENERGYEFFANNRES
# commercial annual energy efficiency energy effects                      ENERGYEFFANNCOM
# industrial annual energy efficiency energy effects                      ENERGYEFFANNIND
# other annual energy efficiency energy effects                           ENERGYEFFANNOTH
# residential incremental energy efficiency actual peak reduction     EEFACTUALPEAKINCRES
# commercial incremental energy efficiency actual peak reduction      EEFACTUALPEAKINCCOM
# industrial incremental energy efficiency actual peak reduction      EEFACTUALPEAKINCIND
# other incremental energy efficiency actual peak reduction           EEFACTUALPEAKINCOTH
# residential annual energy efficiency actual peak reduction          EEFACTUALPEAKANNRES
# commercial annual energy efficiency actual peak reduction           EEFACTUALPEAKANNCOM
# industrial annual energy efficiency actual peak reduction           EEFACTUALPEAKANNIND
# other annual energy efficiency actual peak reduction                EEFACTUALPEAKANNOTH
# residential incremental load management energy effects                 LOADMNGEFFINCRES
# commercial incremental load management energy effects                  LOADMNGEFFINCCOM
# industrial incremental load management energy effects                 LOADMNGEFFINCCIND
# other incremental load management energy effects                       LOADMNGEFFINCOTH
# residential annual load management energy effects                      LOADMNGEFFANNRES
# commercial annual load management energy effects                       LOADMNGEFFANNCOM
# industrial annual load management energy effects                       LOADMNGEFFANNIND
# other annual load management energy effects                            LOADMNGEFFANNOTH
# residential incremental load management potential peak reduction  LMPOTENTPEAKREDINCRES
# commercial incremental load management potential peak reduction   LMPOTENTPEAKREDINCCOM
# industrial incremental load management potential peak reduction   LMPOTENTPEAKREDINCIND
# other incremental load management potential peak reduction        LMPOTENTPEAKREDINCOTH
# residential annual load management potential peak reduction       LMPOTENTPEAKREDANNRES
# commercial annual load management potential peak reduction        LMPOTENTPEAKREDANNCOM
# industrial annual load management potential peak reduction        LMPOTENTPEAKREDANNIND
# other annual load management potential peak reduction             LMPOTENTPEAKREDANNOTH
# residential incremental load management actual peak reduction     LMACTUALPEAKREDINCRES
# commercial incremental load management actual peak reduction      LMACTUALPEAKREDINCCOM
# industrial incremental load management actual peak reduction      LMACTUALPEAKREDINCIND
# other incremental load management actual peak reduction           LMACTUALPEAKREDINCOTH
# residential annual load management actual peak reduction          LMACTUALPEAKREDANNRES
# commercial annual load management actual peak reduction           LMACTUALPEAKREDANNCOM
# industrial annual load management actual peak reduction           LMACTUALPEAKREDANNIND
# other annual load management actual peak reduction                LMACTUALPEAKREDANNOTH
# annual energy efficiency cost                                             DIRECTCOSTEEF
# annual incentive payment energy efficiency                                 INCENTIVEEEF
# annual load management cost                                                DIRECTCOSTLM
# annual incentive payment load management                                    INCENTIVELM
# annual indirect utility cost                                               INDIRECTCOST
# annual total utility cost                                                     TOTALCOST
#
#                                                                               slug_2008
# desc
# utility code                                                                    UTIL_ID
# utility name                                                               UTILITY_NAME
# nerc location                                                             NERC_LOCATION
# sales for resale                                                       SALES_FOR_RESALE
# residential incremental energy efficiency energy effects                ENERGYEFFINCRES
# commercial incremental energy efficiency energy effects                ENERGYEFFINCCOMM
# industrial incremental energy efficiency energy effects                 ENERGYEFFINCIND
# other incremental energy efficiency energy effects                      ENERGYEFFINCOTH
# residential annual energy efficiency energy effects                     ENERGYEFFANNRES
# commercial annual energy efficiency energy effects                      ENERGYEFFANNCOM
# industrial annual energy efficiency energy effects                      ENERGYEFFANNIND
# other annual energy efficiency energy effects                           ENERGYEFFANNOTH
# residential incremental energy efficiency actual peak reduction     EEFACTUALPEAKINCRES
# commercial incremental energy efficiency actual peak reduction      EEFACTUALPEAKINCCOM
# industrial incremental energy efficiency actual peak reduction      EEFACTUALPEAKINCIND
# other incremental energy efficiency actual peak reduction           EEFACTUALPEAKINCOTH
# residential annual energy efficiency actual peak reduction          EEFACTUALPEAKANNRES
# commercial annual energy efficiency actual peak reduction          EEFACTUALPEAKANNCOM
# industrial annual energy efficiency actual peak reduction           EEFACTUALPEAKANNIND
# other annual energy efficiency actual peak reduction                EEFACTUALPEAKANNOTH
# residential incremental load management energy effects                 LOADMNGEFFINCRES
# commercial incremental load management energy effects                  LOADMNGEFFINCCOM
# industrial incremental load management energy effects                 LOADMNGEFFINCCIND
# other incremental load management energy effects                       LOADMNGEFFINCOTH
# residential annual load management energy effects                      LOADMNGEFFANNRES
# commercial annual load management energy effects                       LOADMNGEFFANNCOM
# industrial annual load management energy effects                       LOADMNGEFFANNIND
# other annual load management energy effects                            LOADMNGEFFANNOTH
# residential incremental load management potential peak reduction  LMPOTENTPEAKREDINCRES
# commercial incremental load management potential peak reduction   LMPOTENTPEAKREDINCCOM
# industrial incremental load management potential peak reduction   LMPOTENTPEAKREDINCIND
# other incremental load management potential peak reduction        LMPOTENTPEAKREDINCOTH
# residential annual load management potential peak reduction       LMPOTENTPEAKREDANNRES
# commercial annual load management potential peak reduction        LMPOTENTPEAKREDANNCOM
# industrial annual load management potential peak reduction        LMPOTENTPEAKREDANNIND
# other annual load management potential peak reduction             LMPOTENTPEAKREDINCOTH
# residential incremental load management actual peak reduction     LMACTUALPEAKREDINCRES
# commercial incremental load management actual peak reduction      LMACTUALPEAKREDINCCOM
# industrial incremental load management actual peak reduction      LMACTUALPEAKREDINCIND
# other incremental load management actual peak reduction           LMACTUALPEAKREDINCOTH
# residential annual load management actual peak reduction          LMACTUALPEAKREDANNRES
# commercial annual load management actual peak reduction           LMACTUALPEAKREDANNCOM
# industrial annual load management actual peak reduction           LMACTUALPEAKREDANNIND
# other annual load management actual peak reduction                LMACTUALPEAKREDANNOTH
# annual energy efficiency cost                                             DIRECTCOSTEEF
# annual incentive payment energy efficiency                                 INCENTIVEEEF
# annual load management cost                                                DIRECTCOSTLM
# annual incentive payment load management                                    INCENTIVELM
# annual indirect utility cost                                               INDIRECTCOST
# annual total utility cost                                                     TOTALCOST

# %%
len(field_comb)
# Out:
# 50
